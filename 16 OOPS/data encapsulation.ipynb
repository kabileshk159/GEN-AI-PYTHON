# %%
class Student:
    def __init__(self, name, roll_no, mark1, mark2):
        self.name = name
        self.roll_no = roll_no
        self.mark1 = mark1
        self.mark2 = mark2

    def calculate_total(self):
        total = self.mark1 + self.mark2
        return total

    def display_details(self):
        print("Student Name:", self.name)
        print("Roll Number:", self.roll_no)
        print("Mark 1:", self.mark1)
        print("Mark 2:", self.mark2)
        print("Total Mark:", self.calculate_total())

student1 = Student("Kabil", 101, 85, 90)
student2 = Student("Arun", 102, 75, 80)

student1.display_details()
print("----------------")
student2.display_details()
student2.calculate_total()
# Out:
# Student Name: Kabil
# Roll Number: 101
# Mark 1: 85
# Mark 2: 90
# Total Mark: 175
# ----------------
# Student Name: Arun
# Roll Number: 102
# Mark 1: 75
# Mark 2: 80
# Total Mark: 155
# 155
