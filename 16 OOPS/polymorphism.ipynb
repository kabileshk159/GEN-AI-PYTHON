# %%
class Car:
    def speed(self):
        print("Car is running")


class BMW(Car):
    def speed(self):
        print("BMW speed is 200 km/hr")


class Tesla(Car):
    def speed(self):
        print("Tesla speed is 150 km/hr")



car1 = BMW()
car2 = Tesla()


car1.speed()
car2.speed()
# Out:
# BMW speed is 200 km/hr
# Tesla speed is 150 km/hr
