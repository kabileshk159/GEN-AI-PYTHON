# %%
def ratnamerow(name):
    for i in range(len(name)):
        for j in range(i+1):
            print(name[i],end=' ')
        print()

ratnamerow('kabilesh')
# Out:
# k
# a a
# b b b
# i i i i
# l l l l l
# e e e e e e
# s s s s s s s
# h h h h h h h h

# %%
def ratnamecol(name):
    for i in range(len(name)):
        for j in range(i+1):
            print(name[j],end=' ')
        print()

ratnamecol('kabilesh')
# Out:
# k
# k a
# k a b
# k a b i
# k a b i l
# k a b i l e
# k a b i l e s
# k a b i l e s h

# %%
def ratnameupperrow(name):
    name= name.upper()
    for i in range(len(name)):
        for j in range(i+1):
            print(name[i],end=' ')
        print()
        
ratnameupperrow('kabilesh')
# Out:
# K
# A A
# B B B
# I I I I
# L L L L L
# E E E E E E
# S S S S S S S
# H H H H H H H H

# %%
def ratnameuppercol(name):
    name= name.upper()
    for i in range(len(name)):
        for j in range(i+1):
            print(name[j],end=' ')
        print()
        
ratnameuppercol('kabilesh')
# Out:
# K
# K A
# K A B
# K A B I
# K A B I L
# K A B I L E
# K A B I L E S
# K A B I L E S H

# %%
def iratnamerow(name):
    for i in range(len(name)):
        for j in range(len(name),i,-1):
            print(name[i],end=' ')
        print()
        
iratnamerow('kabilesh')
# Out:
# k k k k k k k k
# a a a a a a a
# b b b b b b
# i i i i i
# l l l l
# e e e
# s s
# h

# %%
def iratnamecol(name):
 for i in range((len(name)),0,-1):
     for j in range(0,i):
         print(name[j],end=' ')
     print()

iratnamecol('kabilesh')
# Out:
# k a b i l e s h
# k a b i l e s
# k a b i l e
# k a b i l
# k a b i
# k a b
# k a
# k

# %%
def iratnameupperrow(name):
    name= name.upper()
    for i in range(len(name)):
        for j in range(len(name),i,-1):
            print(name[i],end=' ')
        print()
        
iratnameupperrow('kabilesh')
# Out:
# K K K K K K K K
# A A A A A A A
# B B B B B B
# I I I I I
# L L L L
# E E E
# S S
# H

# %%
def iratnameuppercol(name):
 name= name.upper() 
 for i in range((len(name)),0,-1):
     for j in range(0,i):
         print(name[j],end=' ')
     print()

iratnameuppercol('kabilesh')
# Out:
# K A B I L E S H
# K A B I L E S
# K A B I L E
# K A B I L
# K A B I
# K A B
# K A
# K

# %%
def latnamerow(name):
 for i in range(len(name)):
    for j in range(len(name),i,-1):
      print(' ',end= ' ')
    for k in range(0,i+1):
      print(name[i],end= ' ')
    print()
latnamerow('kabilesh')
# Out:
#                 k
#               a a
#             b b b
#           i i i i
#         l l l l l
#       e e e e e e
#     s s s s s s s
#   h h h h h h h h

# %%
def latnamecol(name):
 for i in range(len(name)):
     for j in range(len(name),i,-1):
         print(' ',end= ' ')
     for k in range(0,i+1):
         print(name[k],end= ' ')  
     print()
latnamecol('kabilesh')
# Out:
#                 k
#               k a
#             k a b
#           k a b i
#         k a b i l
#       k a b i l e
#     k a b i l e s
#   k a b i l e s h

# %%
def latnameupperrow(name):
 name= name.upper()
 for i in range(len(name)):
    for j in range(len(name),i,-1):
      print(' ',end= ' ')
    for k in range(0,i+1):
      print(name[i],end= ' ')
    print()
latnameupperrow('kabilesh')
# Out:
#                 K
#               A A
#             B B B
#           I I I I
#         L L L L L
#       E E E E E E
#     S S S S S S S
#   H H H H H H H H

# %%
def latnameuppercol(name):
 name=name.upper()
 for i in range(len(name)):
     for j in range(len(name),i,-1):
         print(' ',end= ' ')
     for k in range(0,i+1):
         print(name[k],end= ' ')  
     print()
latnameuppercol('kabilesh')
# Out:
#                 K
#               K A
#             K A B
#           K A B I
#         K A B I L
#       K A B I L E
#     K A B I L E S
#   K A B I L E S H

# %%
def ilatnamerow(name):
 for i in range(len(name),0,-1):
    for j in range(len(name),i,-1):
      print(' ',end= ' ')
    for k in range(0,i):
      print(name[k],end= ' ')
    print()
ilatnamerow('kabilesh')
# Out:
# k a b i l e s h
#   k a b i l e s
#     k a b i l e
#       k a b i l
#         k a b i
#           k a b
#             k a
#               k
