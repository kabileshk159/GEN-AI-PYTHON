# %%
URL= ['www.youtube.com', 'www.cricbuzz.com', 'www.wikipedia.com']
for i in URL:
    print(i.removeprefix('www.'))
# Out:
# youtube.com
# cricbuzz.com
# wikipedia.com

# %%
STUD= ['sid ahmed', 'sridhar vembu', 'sundar pichai','elon musk']
for i in STUD:
    print(i.split(' ')[1].upper())
# Out:
# AHMED
# VEMBU
# PICHAI
# MUSK
